# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import sys
sys.path.append("c:\\users\\lt\\anaconda3\\envs\\pythondata\\lib\\site-packages")
import requests
import gmaps
import gmaps.datasets

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df
# Out:
#     City_ID                       City Country  Max Temp Current Description  \
# 0        38           Vega De Alatorre      MX     86.68    scattered clouds
# 1        40                       Hilo      US     86.29          few clouds
# 2        55              Half Moon Bay      US     87.91          few clouds
# 3        98                 Punto Fijo      VE     86.92       broken clouds
# 4       128                   Altamira      BR     87.89    scattered clouds
# 5       140                    Concord      US     88.29           clear sky
# 6       193                   Catarama      EC     87.03          few clouds
# 7       195                    Pahrump      US     85.24           clear sky
# 8       214                 Ridgecrest      US     85.68           clear sky
# 9       234                 Morant Bay      JM     88.72    scattered clouds
# 10      246                   Acapulco      MX     85.05    scattered clouds
# 11      268                 Balkanabat      TM     88.05           clear sky
# 12      270                 Cataguases      BR     86.65    scattered clouds
# 13      291                     Lodwar      KE     86.85       broken clouds
# 14      314                      Hobbs      US     85.06    scattered clouds
# 15      339                    Bhinmal      IN     87.67           clear sky
# 16      348                 The Valley      AI     85.86          few clouds
# 17      349               Solana Beach      US     87.73    scattered clouds
# 18      376                     Jibuti      DJ     88.07           clear sky
# 19      382                    Humaita      BR     87.93     overcast clouds
# 20      416                     Bosaso      SO     86.36       broken clouds
# 21      421  Santa Isabel Do Rio Negro      BR     85.77       broken clouds
# 22      440                Bodden Town      KY     87.01          few clouds
# 23      518                 Las Juntas      MX     86.94    scattered clouds
# 24      555                   Shorapur      IN     85.59     overcast clouds
# 25      585                Silver City      US     85.68           clear sky
# 26      601                      Butte      US     87.98     overcast clouds
# 27      619              San Cristobal      VE     86.18          few clouds
#
#       Lat     Lng                                Hotel Name
# 0   20.03  -96.63                              Hotel D Luxe
# 1   19.73 -155.09                       Hilo Hawaiian Hotel
# 2   37.46 -122.43           The Ritz-Carlton, Half Moon Bay
# 3   11.70  -70.20                        Santa Fe Inn Hotel
# 4   -3.20  -52.21                            Requinte Hotel
# 5   37.98 -122.03                            Hilton Concord
# 6   -1.58  -79.47                            Hotel Ricaurte
# 7   36.21 -115.98                Best Western Pahrump Oasis
# 8   35.62 -117.67  SpringHill Suites by Marriott Ridgecrest
# 9   17.88  -76.41             Whispering Bamboo Cove Resort
# 10  16.86  -99.89                 HS Hotsson Smart Acapulco
# 11  39.51   54.37                            Nebitchi Hotel
# 12 -21.39  -42.70                               Hotel Viana
# 13   3.12   35.60                     Solmar Gracious Hotel
# 14  32.70 -103.14                Best Western Executive Inn
# 15  25.00   72.25           Jambheswar Bhavan(Gopi Khilery)
# 16  18.22  -63.06              CeBlue Villas & Beach Resort
# 17  32.99 -117.27                  Hilton San Diego/Del Mar
# 18  11.50   42.50                   Orchid Main Camp Goubet
# 19  -7.51  -63.02                              Corrêa Hotel
# 20  11.28   49.18                             Red Sea Hotel
# 21  -0.41  -65.02                                 Hotel GSA
# 22  19.28  -81.25                              Will T Place
# 23  19.42 -104.70                       La casa de la Riata
# 24  16.52   76.75                         Maheshwari Bhawan
# 25  32.77 -108.28                        Copper Manor Motel
# 26  39.65 -121.57         Meadowbrook Oaks Mobile Home Park
# 27   7.77  -72.22                                  Pirineos

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Currrent Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df['City_ID'] == 55]
vacation_end = vacation_df.loc[vacation_df['City_ID'] == 55]
vacation_stop1 = vacation_df.loc[vacation_df['City_ID'] == 601]
vacation_stop2 = vacation_df.loc[vacation_df['City_ID'] == 195] 
vacation_stop3 = vacation_df.loc[vacation_df['City_ID'] == 214]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = (vacation_start['Lat'].to_numpy()[0], vacation_start['Lng'].to_numpy()[0])
end = (vacation_end['Lat'].to_numpy()[0], vacation_end['Lng'].to_numpy()[0])
stop1 = (vacation_stop1['Lat'].to_numpy()[0], vacation_stop1['Lng'].to_numpy()[0])
stop2 = (vacation_stop2['Lat'].to_numpy()[0], vacation_stop2['Lng'].to_numpy()[0])
stop3 = (vacation_stop3['Lat'].to_numpy()[0], vacation_stop3['Lng'].to_numpy()[0])

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

fig = gmaps.figure()
itinerary = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')
fig.add_layer(itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,
                         vacation_stop1,
                         vacation_stop2,
                         vacation_stop3],
                         ignore_index=True)
itinerary_df
# Out:
#    City_ID           City Country  Max Temp Current Description    Lat  \
# 0       55  Half Moon Bay      US     87.91          few clouds  37.46
# 1      601          Butte      US     87.98     overcast clouds  39.65
# 2      195        Pahrump      US     85.24           clear sky  36.21
# 3      214     Ridgecrest      US     85.68           clear sky  35.62
#
#       Lng                                Hotel Name
# 0 -122.43           The Ritz-Carlton, Half Moon Bay
# 1 -121.57         Meadowbrook Oaks Mobile Home Park
# 2 -115.98                Best Western Pahrump Oasis
# 3 -117.67  SpringHill Suites by Marriott Ridgecrest

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Currrent Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
